# %% [markdown]
# <a href="https://colab.research.google.com/github/rahuld11/ANN_with_TensorFlow/blob/master/Samba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pathlib import Path

# %%
# !pip install fuzzymatcher
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 2.9 MB/s eta 0:00:00
# ...
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13902 sha256=3a739ae86eeb2d6dc1b6823c56386b08e5cc34cc09c2d444354b9fcd41ea88e3
#   Stored in directory: /root/.cache/pip/wheels/23/dd/1d/6cdd346605db62bde1f60954155e9ce48f4681c243f265b704
# Successfully built metaphone
# ...

# %%
import fuzzymatcher

# %%
hospital_accounts = pd.read_csv('/content/hospital_account_info.csv')

# %%
hospital_accounts.head()
# Out:
#    Account_Num                      Facility Name                    Address  \
# 0        10605             SAGE MEMORIAL HOSPITAL  STATE ROUTE 264 SOUTH 191
# 1        24250        WOODRIDGE BEHAVIORAL CENTER       600 NORTH 7TH STREET
# 2        10341           DOUGLAS GARDENS HOSPITAL            5200 NE 2ND AVE
# 3        81101  SUNCOAST BEHAVIORAL HEALTH CENTER             4480 51ST ST W
# 4        39835           TREASURE VALLEY HOSPITAL   8800 WEST EMERALD STREET
#
#            City State  ZIP Code County Name    Phone Number  \
# 0        GANADO    AZ     86505      APACHE  (928) 755-4541
# 1  WEST MEMPHIS    AR     72301  CRITTENDEN  (870) 394-4113
# 2         MIAMI    FL     33137  MIAMI-DADE  (305) 751-8626
# 3     BRADENTON    FL     34210     MANATEE  (941) 792-2222
# 4         BOISE    ID     83704         ADA  (208) 373-5000
#
#                Hospital Type              Hospital Ownership
# 0  Critical Access Hospitals  Voluntary non-profit - Private
# ...

# %%
hospital_accounts.columns
# Out:
# Index(['Account_Num', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership'],
#       dtype='object')

# %%
hospital_accounts.dtypes
# Out:
# Account_Num            int64
# Facility Name         object
# Address               object
# City                  object
# State                 object
# ZIP Code               int64
# County Name           object
# Phone Number          object
# Hospital Type         object
# Hospital Ownership    object
# dtype: object

# %%
hospital_accounts.describe()
# Out:
#         Account_Num      ZIP Code
# count   5339.000000   5339.000000
# mean   52493.070238  53823.693950
# std    24804.423079  27117.375614
# min    10020.000000    603.000000
# 25%    30742.000000  32570.000000
# 50%    52387.000000  55101.000000
# 75%    74164.000000  76154.500000
# max    94995.000000  99929.000000

# %%
hospital_accounts.isnull()
hospital_accounts.isnull().sum()
# Out:
# Account_Num           0
# Facility Name         0
# Address               0
# City                  0
# State                 0
# ZIP Code              0
# County Name           0
# Phone Number          0
# Hospital Type         0
# Hospital Ownership    0
# dtype: int64

# %%
hospital_reimbursement = pd.read_csv('/content/hospital_reimbursement.csv')

# %%
hospital_reimbursement.head()
# Out:
#    Provider_Num                     Provider Name     Provider Street Address  \
# 0        839987  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        519118     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        733073    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        201752          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        678488                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
#
#   Provider City Provider State  Provider Zip Code  Total Discharges  \
# 0        DOTHAN             AL              36301               118
# 1          BOAZ             AL              35957                43
# 2      FLORENCE             AL              35631                73
# 3           OPP             AL              36467                12
# 4    BIRMINGHAM             AL              35235                74
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# ...

# %%
hospital_reimbursement.columns
# Out:
# Index(['Provider_Num', 'Provider Name', 'Provider Street Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
#        'Average Medicare Payments'],
#       dtype='object')

# %%
hospital_reimbursement.dtypes
# Out:
# Provider_Num                   int64
# Provider Name                 object
# Provider Street Address       object
# Provider City                 object
# Provider State                object
# Provider Zip Code              int64
# Total Discharges               int64
# Average Covered Charges      float64
# Average Total Payments       float64
# Average Medicare Payments    float64
# dtype: object

# %%
hospital_reimbursement.describe()
# Out:
#         Provider_Num  Provider Zip Code  Total Discharges  \
# count    2697.000000        2697.000000       2697.000000
# mean   501489.655172       49943.255098         67.329255
# std    230745.770655       27863.511795         58.338022
# min    100424.000000        1040.000000         11.000000
# 25%    303792.000000       28659.000000         27.000000
# 50%    499667.000000       46360.000000         49.000000
# 75%    700893.000000       75028.000000         90.000000
# max    899441.000000       99701.000000        505.000000
#
#        Average Covered Charges  Average Total Payments  \
# count              2697.000000             2697.000000
# mean              28018.102421             7180.545577
# std               16318.729170             2137.304822
# min                3638.080000             4245.960000
# 25%               16888.300000             5884.270000
# 50%               23381.090000             6542.650000
# ...

# %%
hospital_reimbursement.isnull()
# Out:
#       Provider_Num  Provider Name  Provider Street Address  Provider City  \
# 0            False          False                    False          False
# 1            False          False                    False          False
# 2            False          False                    False          False
# 3            False          False                    False          False
# 4            False          False                    False          False
# ...            ...            ...                      ...            ...
# 2692         False          False                    False          False
# 2693         False          False                    False          False
# 2694         False          False                    False          False
# 2695         False          False                    False          False
# 2696         False          False                    False          False
#
#       Provider State  Provider Zip Code  Total Discharges  \
# ...

# %%
hospital_reimbursement.isnull().sum()
# Out:
# Provider_Num                 0
# Provider Name                0
# Provider Street Address      0
# Provider City                0
# Provider State               0
# Provider Zip Code            0
# Total Discharges             0
# Average Covered Charges      0
# Average Total Payments       0
# Average Medicare Payments    0
# dtype: int64

# %% [markdown]
# # Since the columns have different names, we need to define which columns to match for the left and right DataFrames. In this case, our hospital account information will be the left DataFrame and the reimbursement info will be the right

# %%
left_on = ['Account_Num', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
       'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership']

# %%
right_on = [
    'Provider_Num', 'Provider Name', 'Provider Street Address',
       'Provider City', 'Provider State', 'Provider Zip Code',
       'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
       'Average Medicare Payments'
]

# %% [markdown]
# # Now we let fuzzymatcher try to figure out the matches using fuzzy_left_join :

# %%
matched_results = fuzzymatcher.fuzzy_left_join(hospital_accounts,
                                            hospital_reimbursement,
                                            left_on,
                                            right_on,
                                            left_id_col='Account_Num',
                                            right_id_col='Provider_Num')

# %%
cols = ["best_match_score",'Account_Num','Provider_Num','Facility Name',
        'Provider Name','Address','Provider Street Address','City','Provider City',
        'ZIP Code','Provider Zip Code','State','Provider State','County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
        'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
        'Average Medicare Payments'

]

# %%
matched_results[cols].sort_values(by=['best_match_score'], ascending=False).head(5)

# %%
matched_results[cols].sort_values(by=['best_match_score'], ascending=True).head(5)

# %%
matched_results[cols].query("best_match_score <= .80").sort_values(
    by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score  Account_Num  Provider_Num  \
# 667065          0.798081        92519        638698
# 178126          0.795841        46442        520689
# 774034          0.794469        56530        320686
# 500372          0.793122        85205        525969
# 56958           0.791911        33681        514196
#
#                                            Facility Name  \
# 667065      NEW YORK-PRESBYTERIAN/HUDSON VALLEY HOSPITAL
# 178126                 TACOMA GENERAL ALLENMORE HOSPITAL
# 774034  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL SOMERSET
# 500372                         SOUTH CENTRAL REG MED CTR
# 56958                          OVERLAND PARK REG MED CTR
#
#                                            Provider Name  \
# 667065      NEW YORK-PRESBYTERIAN/HUDSON VALLEY HOSPITAL
# 178126                 TACOMA GENERAL ALLENMORE HOSPITAL
# 774034  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL SOMERSET
# 500372                         SOUTH CENTRAL REG MED CTR
# ...
